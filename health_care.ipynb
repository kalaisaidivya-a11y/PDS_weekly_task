# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
df=pd.read_csv("healthcare_dataset.csv")
print("Dataset loaded Successfully")
# Out:
# Dataset loaded Successfully

# %%
df.head()
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
df.tail()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission           Doctor                      Hospital  \
# 55495        2020-08-16    Joshua Jarvis                Jones-Thompson
# 55496        2020-01-23  Taylor Sullivan                  Tucker-Moyer
# 55497        2020-07-13   Joe Jacobs DVM  and Mahoney Johnson Vasquez,
# 55498        2019-05-25   Kimberly Curry      Jackson Todd and Castro,
# 55499        2024-04-02    Dennis Warren                Henry Sons and
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# ...

# %%
df.sample()
# Out:
#                  Name  Age Gender Blood Type Medical Condition  \
# 51252  TiMoThY BrIGht   61   Male         A+      Hypertension
#
#       Date of Admission         Doctor                   Hospital  \
# 51252        2021-06-23  Maria Francis  Stokes, and Nash Crawford
#
#       Insurance Provider  Billing Amount  Room Number Admission Type  \
# 51252           Medicare    25337.536074          454       Elective
#
#       Discharge Date   Medication Test Results
# 51252     2021-07-13  Paracetamol     Abnormal

# %%
df.shape
# Out:
# (55500, 15)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Gender', 'Blood Type', 'Medical Condition',
#        'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider',
#        'Billing Amount', 'Room Number', 'Admission Type', 'Discharge Date',
#        'Medication', 'Test Results'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number             int64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
df.info
# Out:
# <bound method DataFrame.info of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
df.describe
# Out:
# <bound method NDFrame.describe of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
df.isnull
# Out:
# <bound method DataFrame.isnull of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
df.isnull().sum()
# Out:
# Name                  0
# Age                   0
# Gender                0
# Blood Type            0
# Medical Condition     0
# Date of Admission     0
# Doctor                0
# Hospital              0
# Insurance Provider    0
# Billing Amount        0
# Room Number           0
# Admission Type        0
# Discharge Date        0
# Medication            0
# Test Results          0
# dtype: int64

# %%
df.dropna()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df.duplicated
# Out:
# <bound method DataFrame.duplicated of                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# ...

# %%
df.drop_duplicates()
# Out:
#                     Name  Age  Gender Blood Type Medical Condition  \
# 0          Bobby JacksOn   30    Male         B-            Cancer
# 1           LesLie TErRy   62    Male         A+           Obesity
# 2            DaNnY sMitH   76  Female         A-           Obesity
# 3           andrEw waTtS   28  Female         O+          Diabetes
# 4          adrIENNE bEll   43  Female        AB+            Cancer
# ...                  ...  ...     ...        ...               ...
# 55495  eLIZABeTH jaCkSOn   42  Female         O+            Asthma
# 55496         KYle pEREz   61  Female        AB-           Obesity
# 55497       HEATher WaNG   38  Female         B+      Hypertension
# 55498     JENniFER JOneS   43    Male         O-         Arthritis
# 55499       jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                      Hospital  \
# 0            2024-01-31     Matthew Smith               Sons and Miller
# ...

# %%
df["Date of Admission"]=pd.to_datetime(df["Date of Admission"], errors="coerce")

# %%
df["Age"] = pd.to_numeric(df["Age"], errors="coerce")

# %%
df["Age"].head()
df["Admission Type"].unique()
# Out:
# array(['Urgent', 'Emergency', 'Elective'], dtype=object)

# %%
df["Gender"].value_counts()
# Out:
# Gender
# Male      27774
# Female    27726
# Name: count, dtype: int64

# %%
df["Medical Condition"].value_counts()
# Out:
# Medical Condition
# Arthritis       9308
# Diabetes        9304
# Hypertension    9245
# Obesity         9231
# Cancer          9227
# Asthma          9185
# Name: count, dtype: int64

# %%
df.groupby("Medical Condition")["Billing Amount"].mean()
# Out:
# Medical Condition
# Arthritis       25497.327056
# Asthma          25635.249359
# Cancer          25161.792707
# Diabetes        25638.405577
# Hypertension    25497.095761
# Obesity         25805.971259
# Name: Billing Amount, dtype: float64

# %%
df.groupby("Medical Condition")["Billing Amount"].agg(["mean","median","min","max","std"])
# Out:
#                            mean        median          min           max  \
# Medical Condition
# Arthritis          25497.327056  25581.763549 -1129.997176  52170.036854
# Asthma             25635.249359  25661.872824 -1520.420555  52181.837792
# Cancer             25161.792707  24910.980640 -2008.492140  52373.032374
# Diabetes           25638.405577  25621.077269 -1316.618581  52211.852966
# Hypertension       25497.095761  25275.670593 -1660.009373  52764.276736
# Obesity            25805.971259  26129.997134 -1310.272895  52024.726443
#
#                             std
# Medical Condition
# Arthritis          14276.529904
# Asthma             14241.677464
# Cancer             14200.271700
# Diabetes           14159.524315
# Hypertension       14305.400942
# Obesity            14079.526507

# %%
df["Age"].std()
# Out:
# 19.602453808513932

# %%
df["Age"].quantile([0.25,0.50,0.75])
# Out:
# 0.25    35.0
# 0.50    52.0
# 0.75    68.0
# Name: Age, dtype: float64

# %%
df["Gender"]=df["Gender"].str.strip()

# %%
df["Medical Condition"]=df["Medical Condition"].str.strip()

# %%
df["Admission Type"]=df["Admission Type"].str.strip()

# %%
df["Insurance Provider"]=df["Insurance Provider"].str.strip()

# %%
df["Gender"]=df["Gender"].str.title()

# %%
df["Medical Condition"]=df["Medical Condition"].str.title()

# %%
df["Admission Type"]=df["Admission Type"].str.title()

# %%
df["Insurance Provider"]=df["Insurance Provider"].str.title()

# %%
df[(df["Age"]>60) & (df["Admission Type"]=="Emergency")]
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 1          LesLie TErRy   62    Male         A+           Obesity
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 12        connOR HANsEn   75  Female         A+          Diabetes
# 24       PAUl hEndERsOn   72  Female        AB+      Hypertension
# 38        NIcOlE LUcErO   70  Female         O-          Diabetes
# ...                 ...  ...     ...        ...               ...
# 55467       SaNDrA ChEN   62  Female         B+            Asthma
# 55471        iaN MuRpHy   73  Female         B+      Hypertension
# 55487    mIsTy RICharDs   78  Female         O-      Hypertension
# 55490  STepHAniE oliVer   82    Male         B-            Cancer
# 55494     JEssIcA WHiTe   67    Male         O+         Arthritis
#
#       Date of Admission             Doctor                       Hospital  \
# 1            2019-08-20    Samantha Davies                        Kim Inc
# ...

# %%
df[(df["Age"] < 30) & (df["Gender"] == "Male")]
# Out:
#                       Name  Age Gender Blood Type Medical Condition  \
# 48            kyLE bEnneTT   22   Male         O+      Hypertension
# 57           MIChael MIllS   23   Male         O-      Hypertension
# 62           tRAvIs carTeR   18   Male         A+            Cancer
# 65            JessIca king   27   Male        AB-            Cancer
# 67            jOhN hARTmAN   27   Male         B-      Hypertension
# ...                    ...  ...    ...        ...               ...
# 55459          Mark RiVEra   25   Male         B-         Arthritis
# 55463        JeNNIFeR WAng   25   Male         A+      Hypertension
# 55472           joHN EVAnS   26   Male        AB-            Asthma
# 55478         gEoRge BAkER   27   Male         B-      Hypertension
# 55483  kimbErlY RIchArDSoN   15   Male         A-          Diabetes
#
#       Date of Admission               Doctor                        Hospital  \
# ...

# %%
df[(df["Age"] > 50) & (df["Gender"] == "Female")]
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 2           DaNnY sMitH   76  Female         A-           Obesity
# 9      ChRISTopher BerG   58  Female        AB-            Cancer
# 12        connOR HANsEn   75  Female         A+          Diabetes
# 13         rObeRt bAuer   68  Female        AB+            Asthma
# 16        haley perkins   63  Female         A+         Arthritis
# ...                 ...  ...     ...        ...               ...
# 55486     AngelA LEstER   83  Female         B+            Asthma
# 55487    mIsTy RICharDs   78  Female         O-      Hypertension
# 55493      gLoRIA BOWen   57  Female         B-         Arthritis
# 55496        KYle pEREz   61  Female        AB-           Obesity
# 55499      jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission            Doctor                     Hospital  \
# 2            2022-09-22  Tiffany Mitchell                     Cook PLC
# ...

# %%
df[(df["Admission Type"] == "Emergency") & (df["Billing Amount"] > 5000)]
# Out:
#                      Name  Age  Gender Blood Type Medical Condition  \
# 1            LesLie TErRy   62    Male         A+           Obesity
# 2             DaNnY sMitH   76  Female         A-           Obesity
# 6          edwArD EDWaRDs   21  Female        AB-          Diabetes
# 7      CHrisTInA MARtinez   20  Female         A+            Cancer
# 12          connOR HANsEn   75  Female         A+          Diabetes
# ...                   ...  ...     ...        ...               ...
# 55487      mIsTy RICharDs   78  Female         O-      Hypertension
# 55488       briTtNeY York   43  Female         B-           Obesity
# 55490    STepHAniE oliVer   82    Male         B-            Cancer
# 55491       lInDA grIFfin   47  Female         O+           Obesity
# 55494       JEssIcA WHiTe   67    Male         O+         Arthritis
#
#       Date of Admission            Doctor                     Hospital  \
# 1            2019-08-20   Samantha Davies                      Kim Inc
# ...

# %%
df[(df["Age"].between(40, 60)) & (df["Admission Type"] == "Urgent")]
# Out:
#                       Name  Age  Gender Blood Type Medical Condition  \
# 4            adrIENNE bEll   43  Female        AB+            Cancer
# 14            bROOkE brady   44  Female        AB+            Cancer
# 21      ChRISToPHEr BRiGhT   48    Male         B+            Asthma
# 22         KatHRYn StewArt   58  Female         O+         Arthritis
# 23     dR. EilEEn thomPsoN   59    Male         A+            Asthma
# ...                    ...  ...     ...        ...               ...
# 55430        MeLisSa ELlIs   43    Male         A+           Obesity
# 55444          dIANE gRaNT   51  Female         O+      Hypertension
# 55477          sUE edWardS   56    Male         O+      Hypertension
# 55482          LUIs BaRbEr   58  Female         B+            Asthma
# 55499         jAMES GARCiA   53  Female         O+         Arthritis
#
#       Date of Admission              Doctor                 Hospital  \
# ...

# %%
df.sort_values("Billing Amount",ascending=False)
# Out:
#                    Name  Age  Gender Blood Type Medical Condition  \
# 36349     tOdd CARrILlO   51  Female         A+      Hypertension
# 34613       kARen klInE   79  Female        AB+            Cancer
# 51313       kARen klInE   74  Female        AB+            Cancer
# 5735     DAVId SanDOvaL   22    Male        AB-      Hypertension
# 7088   kathRYN GoNzales   18  Female         O+          Diabetes
# ...                 ...  ...     ...        ...               ...
# 50099      tErRy WILSOn   43    Male         O-          Diabetes
# 44040    JOsEPH robBins   71    Male         O-      Hypertension
# 42621         joHn hahN   80    Male         O-            Asthma
# 48659       EMMA savAGE   57    Male        AB+      Hypertension
# 47589        james lUnA   64  Female        AB-            Cancer
#
#       Date of Admission             Doctor                     Hospital  \
# 36349        2023-09-08   Kathleen Griffin                Griffin Group
# ...

# %%
condition_summary=(df.groupby("Medical Condition")["Billing Amount"].mean().reset_index())

# %%
df["Length of Stay"]=(pd.to_datetime(df["Discharge Date"])-pd.to_datetime(df["Date of Admission"])).dt.days

# %%
df[["Age","Billing Amount","Room Number","Length of Stay"]].corr()
# Out:
#                      Age  Billing Amount  Room Number  Length of Stay
# Age             1.000000       -0.003832    -0.000720        0.008220
# Billing Amount -0.003832        1.000000    -0.002943       -0.005602
# Room Number    -0.000720       -0.002943     1.000000       -0.005526
# Length of Stay  0.008220       -0.005602    -0.005526        1.000000

# %%
df["Admission Year"]=pd.to_datetime(df["Date of Admission"]).dt.year

# %%
df["Admission Month"]=pd.to_datetime(df["Date of Admission"]).dt.month

# %%
df.groupby("Admission Year")["Billing Amount"].mean()
# Out:
# Admission Year
# 2019    25700.463671
# 2020    25392.254250
# 2021    25629.483239
# 2022    25513.509808
# 2023    25573.848469
# 2024    25380.295013
# Name: Billing Amount, dtype: float64

# %%
monthly_admissions=(df.groupby("Admission Month")["Name"].count().reset_index())

# %%
plt.figure(figsize=(9,5))

# %%
sns.lineplot(data=monthly_admissions, x="Admission Month", y="Name", marker="o")
# Out:
# <Axes: xlabel='Admission Month', ylabel='Name'>

# %%
plt.title("Monthly Number of Admissions")
# Out:
# Text(0.5, 1.0, 'Monthly Number of Admissions')

# %%
plt.xlabel("Admission North")
# Out:
# Text(0.5, 0, 'Admission North')

# %%
plt.ylabel("Number of Admissions")
# Out:
# Text(0, 0.5, 'Number of Admissions')

# %%
plt.show()
